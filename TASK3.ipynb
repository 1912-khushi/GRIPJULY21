# %% [markdown]
# <a href="https://colab.research.google.com/github/1912-khushi/GRIPJULY21/blob/main/TASK3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **The Sparks Foundation #GRIPJULY2021**

# %% [markdown]
# **Data Science and Business Analytics internship**

# %% [markdown]
# **Author: Khushi Kantula**

# %% [markdown]
# **TASK3:Exploratory Data Analysis-Retail**

# %% [markdown]
# **Dataset**:https://bit.ly/3i4rbWl

# %% [markdown]
# ***Importing the Libraries***

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ***Importing the Dataset***

# %%
dataset=pd.read_csv('SampleSuperstore.csv')

# %% [markdown]
# # **Understanding the Data**

# %%
dataset.head()
# Out:
#         Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0    Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1    Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2    Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3  Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4  Standard Class   Consumer  United States  ...        2     0.20    2.5164
#
# [5 rows x 13 columns]

# %%
dataset.tail()
# Out:
#            Ship Mode   Segment        Country  ... Quantity Discount   Profit
# 9989    Second Class  Consumer  United States  ...        3      0.2   4.1028
# 9990  Standard Class  Consumer  United States  ...        2      0.0  15.6332
# 9991  Standard Class  Consumer  United States  ...        2      0.2  19.3932
# 9992  Standard Class  Consumer  United States  ...        4      0.0  13.3200
# 9993    Second Class  Consumer  United States  ...        2      0.0  72.9480
#
# [5 rows x 13 columns]

# %%
dataset.shape
# Out:
# (9994, 13)

# %%
dataset.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %%
dataset.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %%
dataset.columns
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %% [markdown]
# # **Cleaning the Data**

# %%
dataset.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %%
dataset.duplicated().sum()
# Out:
# 17

# %%
dataset.drop_duplicates()
# Out:
#            Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0       Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1       Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2       Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3     Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4     Standard Class   Consumer  United States  ...        2     0.20    2.5164
# ...              ...        ...            ...  ...      ...      ...       ...
# 9989    Second Class   Consumer  United States  ...        3     0.20    4.1028
# 9990  Standard Class   Consumer  United States  ...        2     0.00   15.6332
# 9991  Standard Class   Consumer  United States  ...        2     0.20   19.3932
# 9992  Standard Class   Consumer  United States  ...        4     0.00   13.3200
# 9993    Second Class   Consumer  United States  ...        2     0.00   72.9480
#
# ...

# %% [markdown]
# ***Checking statistical relation between various rows and columns***

# %%
dataset.corr()
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
dataset.cov()
# Out:
#               Postal Code          Sales    Quantity    Discount         Profit
# Postal Code  1.028080e+09 -476682.766590  910.415885  386.870404 -225045.849445
# Sales       -4.766828e+05  388434.455308  278.459923   -3.627228   69944.096586
# Quantity     9.104159e+02     278.459923    4.951113    0.003961      34.534769
# Discount     3.868704e+02      -3.627228    0.003961    0.042622     -10.615173
# Profit      -2.250458e+05   69944.096586   34.534769  -10.615173   54877.798055

# %% [markdown]
# # **Data Visualization**

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(dataset['Sales'],color='red',label="Sales",shade=True,bw=25)
sns.kdeplot(dataset['Profit'],color='yellow',label='Profit',shade=True,bw=25)
plt.xlim([-100,1000])
plt.legend()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:1657: FutureWarning: The `bw` parameter is deprecated in favor of `bw_method` and `bw_adjust`. Using 25 for `bw_method`, but please see the docs for the new parameters and update your code.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ***Based on the Category***

# %%
sns.pairplot(dataset,hue='Category')

# %% [markdown]
# ***Based on Region***

# %%
sns.pairplot(dataset,hue='Region')

# %% [markdown]
# ***Based on the Segment***

# %%
sns.pairplot(dataset,hue='Segment')

# %% [markdown]
# ***Heatmap For Correlation***

# %%
corelation=dataset.corr()
corelation
# Out:
#              Postal Code     Sales  Quantity  Discount    Profit
# Postal Code     1.000000 -0.023854  0.012761  0.058443 -0.029961
# Sales          -0.023854  1.000000  0.200795 -0.028190  0.479064
# Quantity        0.012761  0.200795  1.000000  0.008623  0.066253
# Discount        0.058443 -0.028190  0.008623  1.000000 -0.219487
# Profit         -0.029961  0.479064  0.066253 -0.219487  1.000000

# %%
sns.heatmap(corelation,xticklabels=corelation.columns,yticklabels=corelation.columns,annot=True)

# %% [markdown]
# # **State wise Deal Analysis**

# %%
dataset['Country'].value_counts()
# Out:
# United States    9994
# Name: Country, dtype: int64

# %%
dataset1=dataset['State'].value_counts()
dataset1.head(10)
# Out:
# California        2001
# New York          1128
# Texas              985
# Pennsylvania       587
# Washington         506
# Illinois           492
# Ohio               469
# Florida            383
# Michigan           255
# North Carolina     249
# Name: State, dtype: int64

# %%
dataset1.plot(kind='bar',figsize=(15,5))
plt.ylabel('Frequency/Number of deals')
plt.xlabel("States")
plt.title("State Wise Dealings",fontsize=20)
plt.show()

# %% [markdown]
# *   **The top three states where the deals are Highest**
#
#
# 1.   California
# 2.   New York
#
# 1.   Texas

# %%
dataset['State'].value_counts().mean()
# Out:
# 203.9591836734694

# %% [markdown]
# **average number of deal per state is 203.95**

# %% [markdown]
# # **City Wise Deal Analysis**

# %%
dataset2=dataset['City'].value_counts()
dataset2=dataset2.head(50)

# %%
dataset2.plot(kind='bar',figsize=(15,5))
plt.ylabel('Frequency /Number of Deals')
plt.xlabel("City")
plt.title("City wise dealings",fontsize=20)
plt.show()

# %% [markdown]
# *   **Top 3 cities with highest deals**
#
#
# 1.   New York City
#
# 1.   Los Angeles
# 2.   Philadelphia

# %%
dataset['City'].value_counts().mean()
# Out:
# 18.821092278719398

# %% [markdown]
# **Average number of deals per city is 18.8**

# %% [markdown]
# # **Segment Wise analysis of Profit,Discount and Sales**

# %%
dataset['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
dataset_Segment=dataset.groupby(['Segment'])[['Profit','Discount','Sales']].mean()
dataset_Segment
# Out:
#                 Profit  Discount       Sales
# Segment
# Consumer     25.836873  0.158141  223.733644
# Corporate    30.456667  0.158228  233.823300
# Home Office  33.818664  0.147128  240.972041

# %%
dataset_Segment.plot.pie(subplots=True,
                         autopct='%1.1f%%',
                         figsize=(18,20),
                         startangle=90,
                         shadow=True,
                         labels=dataset_Segment.index)
plt.title("Segment wise analysis of Profit,Discount,Profit")
# Out:
# Text(0.5, 1.0, 'Segment wise analysis of Profit,Discount,Profit')

# %% [markdown]
# **Profit:**
#
#
# *   Consumer:28.7%
#
# *   Corporate:33.8%
#
# *   Home Office:37.5%
#
# **Discount:**
#
#
# *   Consumer:15.8%
#
# *   Corporate:15.8%
# *   Home Office:14.7%
#
# **Sales:**
#
#
# *   Consumer:32.0%
#
# *   Corporate:33.5%
# *   Home Office:34.5%

# %% [markdown]
# # **State Wise analysis of Profit, Discount and sales**

# %%
dataset['State'].value_counts().head(10)
# Out:
# California        2001
# New York          1128
# Texas              985
# Pennsylvania       587
# Washington         506
# Illinois           492
# Ohio               469
# Florida            383
# Michigan           255
# North Carolina     249
# Name: State, dtype: int64

# %%
dataset_state=dataset.groupby(['State'])[['Sales','Discount','Profit']].mean()
dataset.head(10)
# Out:
#         Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0    Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1    Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2    Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3  Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4  Standard Class   Consumer  United States  ...        2     0.20    2.5164
# 5  Standard Class   Consumer  United States  ...        7     0.00   14.1694
# 6  Standard Class   Consumer  United States  ...        4     0.00    1.9656
# 7  Standard Class   Consumer  United States  ...        6     0.20   90.7152
# 8  Standard Class   Consumer  United States  ...        3     0.20    5.7825
# 9  Standard Class   Consumer  United States  ...        5     0.00   34.4700
#
# [10 rows x 13 columns]

# %% [markdown]
# **[1]Statewise Profit Analysis**

# %%
dataset_state1=dataset_state.sort_values('Profit')
dataset_state1[['Profit']].plot(kind='bar',figsize=(15,4))
plt.title('State wise Profit analysis',fontsize=20)
plt.ylabel('Profit per state')
plt.xlabel('States')
plt.show()

# %% [markdown]
# *   **Vermont**: Highest Profit
# *   **Ohio**: Lowest Profit

# %% [markdown]
# **[2]Statewise Sales Analysis**

# %%
dataset_state['Sales'].plot(kind='bar',
                            figsize=(15,4))
plt.title("State wise analysis of sales ",fontsize=20)
plt.ylabel('Sales per state')
plt.xlabel('States')
plt.show()

# %% [markdown]
# *  Highest amount of sales:**Wyoming**
# *  Lowest amount of sales: **South Dakota**

# %% [markdown]
# **[3]Statewise Discount Analysis**

# %%
dataset_state['Discount'].plot(kind='bar',figsize=(18,5))
plt.title("State wise analysis of Discount",fontsize=20)
# Out:
# Text(0.5, 1.0, 'State wise analysis of Discount')

# %% [markdown]
# *   **Illinois at the top**

# %% [markdown]
# # **City wise analysis of the Profit, Discount, Sales**

# %%
dataset_city=dataset.groupby(['City'])[['Sales','Discount','Profit']].mean()
dataset_city=dataset_city.sort_values('Profit')
dataset_city.head()
# Out:
#                  Sales  Discount      Profit
# City
# Bethlehem   337.926800  0.380000 -200.619160
# Champaign   151.960000  0.600000 -182.352000
# Oswego      107.326000  0.600000 -178.709200
# Round Rock  693.436114  0.274286 -169.061614
# Lancaster   215.031826  0.315217 -157.371052

# %%
dataset_city['Profit'].head(30).plot(kind='bar',figsize=(15,5),color='red')
plt.title("City wise analysis of sale,discount,profit")
# Out:
# Text(0.5, 1.0, 'City wise analysis of sale,discount,profit')

# %%
dataset_city['Profit'].tail(30).plot(kind='bar',figsize=(15,5),color='red')
plt.title('City wise analysis of Sale,Discount,Profit')
# Out:
# Text(0.5, 1.0, 'City wise analysis of Sale,Discount,Profit')

# %% [markdown]
# **There is a good Balance here**

# %% [markdown]
# # **Quantity wise Sales , Profit and Discount Analysis**

# %%
dataset_quantity = dataset.groupby(['Quantity'])[['Sales','Discount','Profit']].mean()
dataset_quantity.head(10)
# Out:
#                Sales  Discount     Profit
# Quantity
# 1          59.234632  0.152959   8.276396
# 2         120.354488  0.154858  16.006831
# 3         175.201578  0.153329  23.667715
# 4         271.764059  0.157708  37.131310
# 5         337.936339  0.157146  40.257394
# 6         362.101960  0.166556  18.051517
# 7         395.888393  0.161980  56.579163
# 8         458.210802  0.171595  42.244342
# 9         498.083683  0.147946  68.557716
# 10        422.046737  0.190702  35.862404

# %%
dataset_quantity.plot.pie(subplots=True,
                          autopct='%1.1f%%',
                          figsize=(20,20),
                          pctdistance=0.69,
                          startangle=90,
                          shadow=True,
                          labels=dataset_quantity.index)
plt.title("Quantity wise analysis of sale,dicount,profit")
# Out:
# Text(0.5, 1.0, 'Quantity wise analysis of sale,dicount,profit')

# %% [markdown]
# 13 Number of Quantity is high for sales and profit

# %% [markdown]
# # **Category wise profit,discount and sales**

# %%
dataset_category=dataset.groupby(['Category'])[['Sales','Discount','Profit']].mean()
dataset_category
# Out:
#                       Sales  Discount     Profit
# Category
# Furniture        349.834887  0.173923   8.699327
# Office Supplies  119.324101  0.157285  20.327050
# Technology       452.709276  0.132323  78.752002

# %%
dataset_category.plot.pie(subplots=True,
                          figsize=(18,20),
                          autopct='%1.1f%%',
                          labels=dataset_category.index)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f5258619950>,
# ...
#       dtype=object)

# %% [markdown]
# *  **Technology** has Maximum sales and Profits
# *   **Furniture** has minimum profit

# %% [markdown]
# # **Sub-Category wise Sales , Profit and Discount**

# %%
dataset_sub_category=dataset.groupby(['Sub-Category'])[['Sales','Discount',"Profit"]].mean()
dataset_sub_category.head(10)
# Out:
#                     Sales  Discount      Profit
# Sub-Category
# Accessories    215.974604  0.078452   54.111788
# Appliances     230.755710  0.166524   38.922758
# Art             34.068834  0.074874    8.200737
# Binders        133.560560  0.372292   19.843574
# Bookcases      503.859633  0.211140  -15.230509
# Chairs         532.332420  0.170178   43.095894
# Copiers       2198.941618  0.161765  817.909190
# Envelopes       64.867724  0.080315   27.418019
# Fasteners       13.936774  0.082028    4.375660
# Furnishings     95.825668  0.138349   13.645918

# %%
dataset_sub_category.sort_values('Profit')[['Sales','Profit']].plot(kind='bar',figsize=(10,5),label=['Average Sales and Profits '])

# %% [markdown]
# **Copier**:Highest Profit as well as Sales

# %% [markdown]
# # **Region Wise Analysis**

# %%
dataset_region=dataset.groupby(["Region"])[['Sales','Discount','Profit']].mean()
dataset_region
# Out:
#               Sales  Discount     Profit
# Region
# Central  215.772661  0.240353  17.092709
# East     238.336110  0.145365  32.135808
# South    241.803645  0.147253  28.857673
# West     226.493233  0.109335  33.849032

# %%
dataset_region.plot.pie(subplots=True,
                        figsize=(18,20),
                        autopct='%1.1f%%',
                        labels=dataset_region.index)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x7f5258def050>,
# ...
#       dtype=object)

# %% [markdown]
# *   Sales: **Southern** part has the highest number of sales
# *   Discount: **Central** part has the highest number of discounts.
#
# *   Profit: **Western** part has the highest profit

# %% [markdown]
# # **Thank you !!**
